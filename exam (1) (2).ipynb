# %%
import pandas as pd

# %%
df=pd.read_excel("marketing_data.xlsx")

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome          Dt_Customer  Recency  MntWines  ...  \
# ...

# %%
for x in df.index:
    if df.loc[x,"Year_Birth"] >1954:
        print(df.loc[x,"ID"])
# Out:
# 1826
# 1
# 10476
# 1386
# 5371
# 7348
# 1991
# 5642
# 10530
# 2964
# 10311
# 837
# 10521
# 10175
# 1473
# 2795
# 115
# 10470
# 4065
# 10968
# 5985
# 5430
# 8432
# 453
# 9687
# 8890
# 9264
# 5824
# 5794
# 3068
# 7962
# 2681
# 10141
# 3725
# 3767
# 5585
# 7030
# 1524
# 3657
# 5740
# 9595
# 3158
# 5114
# 340
# 8805
# 1241
# 7264
# 1619
# 6398
# 4877
# 3066
# 10286
# 1992
# 4246
# 10623
# 4867
# 3112
# 4865
# 6287
# 4405
# 5332
# 1519
# 9080
# 1772
# 5341
# 5510
# 3887
# 7022
# 9999
# 10352
# 7919
# 4114
# 9888
# 4399
# 4452
# 4785
# 8461
# 3878
# 9612
# 4098
# 3896
# 9970
# 4002
# 10914
# 7279
# 10582
# 4470
# 6183
# 8601
# 4827
# 10676
# 1041
# 492
# 11133
# 1631
# 8278
# 6815
# 254
# 1349
# 2130
# 2296
# 3799
# 11084
# 5172
# 850
# 4477
# 1945
# 7685
# 6310
# 10832
# 3025
# 2404
# 8581
# 8920
# 8430
# 8619
# 8996
# 7233
# 6678
# 830
# 6365
# 6770
# 2261
# 1031
# 10089
# 9256
# 10641
# 624
# 4211
# 1407
# 10356
# 6343
# 8275
# 10673
# 8799
# 67
# 9923
# 2814
# 2711
# 4320
# 10451
# ...

# %%
df_sd=df["MntFruits"].std()
print(df_sd)
# Out:
# 39.77343376457871

# %%
for y in df.index:
    if df.loc[y,"Marital_Status"]=="Married":
        print(df.loc[y,"ID"])
# Out:
# 10476
# 4073
# 4047
# 9477
# 2079
# 2964
# 10311
# 837
# 10521
# 10470
# 4065
# 9264
# 5794
# 3068
# 2681
# 3767
# 7030
# 3158
# 5114
# 1241
# 1402
# 1619
# 6398
# 4877
# 10286
# 1992
# 3112
# 4405
# 5332
# 1772
# 5510
# 7022
# 4114
# 7990
# 4098
# 3896
# 4002
# 10582
# 4470
# 6183
# 8601
# 10676
# 4491
# 873
# 8278
# 6815
# 1349
# 2534
# 2296
# 3799
# 9504
# 1945
# 7685
# 6310
# 2404
# 8581
# 8755
# 8996
# 7233
# 6365
# 6770
# 2261
# 1031
# 4211
# 1407
# 6343
# 10673
# 8799
# 944
# 8151
# 6184
# 3498
# 2870
# 10862
# 8216
# 1212
# 2541
# 7872
# 4290
# 7408
# 7284
# 9529
# 10270
# 10669
# 9723
# 5621
# 10995
# 5331
# 10084
# 6019
# 10909
# 5547
# 8362
# 466
# 11025
# 25
# 8159
# 7628
# 9597
# 1384
# 3885
# 8026
# 5429
# 5074
# 2632
# 2521
# 4301
# 2407
# 9064
# 1994
# 1183
# 967
# 1048
# 3427
# 5892
# 8911
# 6606
# 10490
# 7849
# 4808
# 9303
# 8707
# 6271
# 9635
# 9727
# 10681
# 5156
# 3050
# 8164
# 6406
# 6116
# 291
# 8779
# 1650
# 6431
# 10789
# 5929
# 10795
# 1577
# 4609
# 5029
# ...

# %%
for z in df.index:
    if df.loc[z,"Income"]>49000:
     if df.loc[z,"Education"]=="Graduation":
        print(df.loc[z,"ID"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-cd63c14184c3> in <module>
#       1 for z in df.index:
# ----> 2     if df.loc[z,"Income"]>"49000":
#       3      if df.loc[z,"Education"]=="Graduation":
#       4         print(df.loc[z,"ID"])
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
df.plot(x = 'MntFishProducts',y = 'NumCatalogPurchases')
# Out:
# <AxesSubplot:xlabel='MntFishProducts'>

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
# ...

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel("financial_analytics.xlsx")

# %%
df
# Out:
#    Income    HRA  Insurance     DA
# 0  748461  21339     190250  11617

# %%
income=df.loc[0,"Income"]
hra=df.loc[0,"HRA"]
insurance=df.loc[0,"Insurance"]
da=df.loc[0,"DA"]
if insurance<150000:
    tax1=0
else:
    tax1=(10/100)*(insurance-150000)
if income<=250000:
    tax2=0
if income<=500000:
    tax2=5/100*(income-250000)
if income<=750000:
    tax2=12500+((10/100)*(income-500000))
if income<=1000000:
    tax2=37500+((15/100)*(income-750000))
if income<=1250000:
    tax2=75000+((20/100)*(income-1000000))
if income<=1500000:
    tax2=125000+((25/100)*(income-1250000))
if income>1500000:
    tax2=187500+((30-100)*(income-1500000))
if hra<(10/100)*x:
    tax3=0
else:
    tax3=(50/100)*(hra-(10/100)*income)
if da<10000:
    tax4=0
else:
    tax4=(10/100)*(da-10000)
finaltax=tax1+tax2+tax3+tax4
print("final_tax",finaltax)
print("case1",tax1)
print("case2",tax2)
print("case3",tax3)
print("case4",tax4)
# Out:
# final_tax -22951.600000000002
# case1 4025.0
# case2 -384.75
# case3 -26753.550000000003
# case4 161.70000000000002
